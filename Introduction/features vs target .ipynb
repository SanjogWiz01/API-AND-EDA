# %%
import pandas as pd
data = {
    "Age": [22, 25, 30, 35],
    "Salary": [20000, 30000, 40000, 50000],
    "City": ["Pokhara", "Kathmandu", "Pokhara", "Butwal"],
    "Bought": [0, 1, 1, 0]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Age  Salary       City  Bought
# 0   22   20000    Pokhara       0
# 1   25   30000  Kathmandu       1
# 2   30   40000    Pokhara       1
# 3   35   50000     Butwal       0

# %%
#identifing the data types
print(df.dtypes)
# Out:
# Age        int64
# Salary     int64
# City      object
# Bought     int64
# dtype: object

# %%
X = df.drop(["Bought", "City"], axis=1)  # Features
y = df[["Bought", "City"]]               # Targets
# here we will compare about features and targets in this

# %%
print("Features:")
print(X)

print("\nTarget:")
print(y)
# Out:
# Features:
#    Age  Salary
# 0   22   20000
# 1   25   30000
# 2   30   40000
# 3   35   50000
#
# Target:
#    Bought       City
# 0       0    Pokhara
# 1       1  Kathmandu
# 2       1    Pokhara
# 3       0     Butwal

# %%
# sepate the featues
numerical_features = df.select_dtypes(include=['int64','float64'])

categorical_features = df.select_dtypes(include=['object'])

print("Numerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
#    Age  Salary  Bought
# 0   22   20000       0
# 1   25   30000       1
# 2   30   40000       1
# 3   35   50000       0
#
# Categorical Features:
#         City
# 0    Pokhara
# 1  Kathmandu
# 2    Pokhara
# 3     Butwal

# %%
print(df.head())
# Out:
#    Age  Salary       City  Bought
# 0   22   20000    Pokhara       0
# 1   25   30000  Kathmandu       1
# 2   30   40000    Pokhara       1
# 3   35   50000     Butwal       0

# %%
print(df.info()) # describe the details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     4 non-null      int64
#  1   Salary  4 non-null      int64
#  2   City    4 non-null      object
#  3   Bought  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
# None

# %%
print(df.describe())
# Out:
#              Age        Salary   Bought
# count   4.000000      4.000000  4.00000
# mean   28.000000  35000.000000  0.50000
# std     5.715476  12909.944487  0.57735
# min    22.000000  20000.000000  0.00000
# 25%    24.250000  27500.000000  0.00000
# 50%    27.500000  35000.000000  0.50000
# 75%    31.250000  42500.000000  1.00000
# max    35.000000  50000.000000  1.00000

# %%
print(df.isnull().sum())
# Out:
# Age       0
# Salary    0
# City      0
# Bought    0
# dtype: int64
